# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("/content/globalterrorismdb_0718dist.csv", encoding="ISO-8859-1")

# %%
data.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0      0.0       0.0      0.0     0.0      NaN
# 1      0.0       1.0      1.0     1.0      NaN
# 2     -9.0      -9.0      1.0     1.0      NaN
# 3     -9.0      -9.0      1.0     1.0      NaN
# 4     -9.0      -9.0      1.0     1.0      NaN
#
# [5 rows x 135 columns]

# %%
data.describe()
# Out:
#             eventid         iyear        imonth          iday      extended  \
# count  4.596400e+04  45964.000000  45964.000000  45964.000000  45964.000000
# mean   1.983626e+11   1983.561787      6.313528     15.331477      0.016513
# std    5.063982e+08      5.065228      3.408719      8.836873      0.127439
# min    1.970000e+11   1970.000000      0.000000      0.000000      0.000000
# 25%    1.980072e+11   1980.000000      3.000000      8.000000      0.000000
# 50%    1.984082e+11   1984.000000      6.000000     15.000000      0.000000
# 75%    1.988052e+11   1988.000000      9.000000     23.000000      0.000000
# max    1.991033e+11   1991.000000     12.000000     31.000000      1.000000
#
#             country        region      latitude     longitude   specificity  \
# count  45964.000000  45964.000000  43479.000000  4.347900e+04  45964.000000
# mean     153.018188      5.271691     16.909789 -2.005662e+03      1.414237
# std      138.826185      3.167856     25.246486  4.133294e+05      1.096074
# min        4.000000      1.000000    -53.154613 -8.618590e+07      1.000000
# 25%       61.000000      3.000000      4.667128 -7.697846e+01      1.000000
# 50%      110.000000      3.000000     14.152916 -1.543001e+01      1.000000
# 75%      185.000000      8.000000     38.908642  2.787027e+01      1.000000
# max      605.000000     12.000000     64.837778  1.784419e+02      5.000000
#
#        ...     ransomamt  ransomamtus    ransompaid  ransompaidus  \
# count  ...  5.350000e+02          1.0  1.180000e+02           2.0
# mean   ...  3.381788e+06      20000.0  1.072952e+06           0.0
# std    ...  4.362743e+07          NaN  4.226059e+06           0.0
# min    ...  0.000000e+00      20000.0  0.000000e+00           0.0
# 25%    ...  0.000000e+00      20000.0  0.000000e+00           0.0
# 50%    ...  0.000000e+00      20000.0  3.135000e+04           0.0
# 75%    ...  4.889750e+05      20000.0  5.000000e+05           0.0
# max    ...  1.000000e+09      20000.0  4.100000e+07           0.0
#
#        hostkidoutcome   nreleased       INT_LOG      INT_IDEO      INT_MISC  \
# count     1110.000000  838.000000  45963.000000  45963.000000  45963.000000
# mean         3.021622    8.867542     -3.155995     -3.109632      0.153428
# std          1.360754   33.428257      4.366847      4.421222      0.718084
# min          2.000000  -99.000000     -9.000000     -9.000000     -9.000000
# 25%          2.000000    1.000000     -9.000000     -9.000000      0.000000
# 50%          2.000000    1.000000      0.000000      0.000000      0.000000
# 75%          4.000000    2.000000      0.000000      0.000000      0.000000
# max          7.000000  390.000000      1.000000      1.000000      1.000000
#
#             INT_ANY
# count  45963.000000
# mean      -2.425386
# std        4.313987
# min       -9.000000
# 25%       -9.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
#
# [8 rows x 78 columns]

# %%
data.shape
# Out:
# (45964, 135)

# %%
data.isnull().sum()
# Out:
# eventid           0
# iyear             0
# imonth            0
# iday              0
# approxdate    45938
#               ...
# INT_LOG           1
# INT_IDEO          1
# INT_MISC          1
# INT_ANY           1
# related       41531
# Length: 135, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45964 entries, 0 to 45963
# Columns: 135 entries, eventid to related
# dtypes: float64(60), int64(18), object(57)
# memory usage: 47.3+ MB

# %%
plt.figure(figsize=(20,5))
sns.heatmap(data.isnull(),yticklabels=False,cbar=False,cmap="YlGnBu")
# Out:
# <Axes: >

# %%
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)
pd.set_option('display.width',None)
data.isnull().sum()
# Out:
# eventid                   0
# iyear                     0
# imonth                    0
# iday                      0
# approxdate            45938
# extended                  0
# resolution            45204
# country                   0
# country_txt               0
# region                    0
# region_txt                0
# provstate               181
# city                      0
# latitude               2485
# longitude              2485
# specificity               0
# vicinity                  0
# location              45219
# summary               44743
# crit1                     0
# crit2                     0
# crit3                     0
# doubtterr                 0
# alternative           38339
# alternative_txt       38339
# multiple                  0
# success                   0
# suicide                   0
# attacktype1               0
# attacktype1_txt           0
# attacktype2           45923
# attacktype2_txt       45923
# attacktype3           45962
# attacktype3_txt       45962
# targtype1                 0
# targtype1_txt             0
# targsubtype1           2048
# targsubtype1_txt       2048
# corp1                 25167
# target1                 382
# natlty1                 212
# natlty1_txt             212
# targtype2             45437
# targtype2_txt         45437
# targsubtype2          45570
# targsubtype2_txt      45570
# corp2                 45629
# target2               45502
# natlty2               45489
# natlty2_txt           45489
# targtype3             45885
# targtype3_txt         45885
# targsubtype3          45906
# targsubtype3_txt      45906
# corp3                 45923
# target3               45885
# natlty3               45887
# natlty3_txt           45887
# gname                     1
# gsubname              44239
# gname2                45851
# gsubname2             45963
# gname3                45953
# gsubname3             45964
# motive                45023
# guncertain1               1
# guncertain2           45851
# guncertain3           45953
# individual                1
# nperps                39171
# nperpcap              44743
# claimed               44739
# claimmode             45651
# claimmode_txt         45651
# claim2                45945
# claimmode2            45946
# claimmode2_txt        45946
# claim3                45956
# claimmode3            45956
# claimmode3_txt        45956
# compclaim             45917
# weaptype1                 1
# weaptype1_txt             1
# weapsubtype1           7050
# weapsubtype1_txt       7050
# weaptype2             43255
# weaptype2_txt         43255
# weapsubtype2          43706
# weapsubtype2_txt      43706
# weaptype3             45606
# weaptype3_txt         45606
# weapsubtype3          45653
# weapsubtype3_txt      45653
# weaptype4             45898
# weaptype4_txt         45898
# weapsubtype4          45902
# weapsubtype4_txt      45902
# weapdetail             3765
# nkill                  5706
# nkillus               43124
# nkillter              43177
# nwound                 7534
# nwoundus              43173
# nwoundte              43458
# property                  1
# propextent            29819
# propextent_txt        29819
# propvalue             36897
# propcomment           43050
# ishostkid               175
# nhostkid              43092
# nhostkidus            43092
# nhours                45066
# ndays                 45309
# divert                45842
# kidhijcountry         44110
# ransom                  353
# ransomamt             45429
# ransomamtus           45963
# ransompaid            45846
# ransompaidus          45962
# ransomnote            45958
# hostkidoutcome        44854
# hostkidoutcome_txt    44854
# nreleased             45126
# addnotes              45034
# scite1                44743
# scite2                44877
# scite3                45197
# dbsource                  1
# INT_LOG                   1
# INT_IDEO                  1
# INT_MISC                  1
# INT_ANY                   1
# related               41531
# dtype: int64

# %%
data.columns.values
# Out:
# array(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity',
#        'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3',
#        'doubtterr', 'alternative', 'alternative_txt', 'multiple',
#        'success', 'suicide', 'attacktype1', 'attacktype1_txt',
#        'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt',
#        'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt',
#        'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2',
#        'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2',
#        'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt',
#        'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3',
#        'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2',
#        'gname3', 'gsubname3', 'motive', 'guncertain1', 'guncertain2',
#        'guncertain3', 'individual', 'nperps', 'nperpcap', 'claimed',
#        'claimmode', 'claimmode_txt', 'claim2', 'claimmode2',
#        'claimmode2_txt', 'claim3', 'claimmode3', 'claimmode3_txt',
#        'compclaim', 'weaptype1', 'weaptype1_txt', 'weapsubtype1',
#        'weapsubtype1_txt', 'weaptype2', 'weaptype2_txt', 'weapsubtype2',
#        'weapsubtype2_txt', 'weaptype3', 'weaptype3_txt', 'weapsubtype3',
#        'weapsubtype3_txt', 'weaptype4', 'weaptype4_txt', 'weapsubtype4',
#        'weapsubtype4_txt', 'weapdetail', 'nkill', 'nkillus', 'nkillter',
#        'nwound', 'nwoundus', 'nwoundte', 'property', 'propextent',
#        'propextent_txt', 'propvalue', 'propcomment', 'ishostkid',
#        'nhostkid', 'nhostkidus', 'nhours', 'ndays', 'divert',
#        'kidhijcountry', 'ransom', 'ransomamt', 'ransomamtus',
#        'ransompaid', 'ransompaidus', 'ransomnote', 'hostkidoutcome',
#        'hostkidoutcome_txt', 'nreleased', 'addnotes', 'scite1', 'scite2',
#        'scite3', 'dbsource', 'INT_LOG', 'INT_IDEO', 'INT_MISC', 'INT_ANY',
#        'related'], dtype=object)

# %%
datanew=data[['iyear' , 'imonth','iday','country_txt','provstate','region_txt','city','latitude','longitude',
         'attacktype1_txt','nkill','nwound','target1','summary','gname','targtype1_txt','weaptype1_txt','motive']]

# %%
datanew.rename(columns={'iyear':'YEAR','imonth':'MONTH','iday':"DAY",'gname':'GROUP','country_txt':'COUNTRY','region_txt':'REGION','provstate':'STATE','attacktype1_txt':'ATTACK_TYPE','targtype1_txt':'TARGET_TYPE','weaptype1_txt':'WEAPON','nkill':'KILL',
     'nwound':'WOUND'},inplace=True)
datanew.head()
# Out:
#    YEAR  MONTH  DAY             COUNTRY    STATE                       REGION  \
# 0  1970      7    2  Dominican Republic      NaN  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
# 2  1970      1    0         Philippines   Tarlac               Southeast Asia
# 3  1970      1    0              Greece   Attica               Western Europe
# 4  1970      1    0               Japan  Fukouka                    East Asia
#
#             city   latitude   longitude                     ATTACK_TYPE  KILL  \
# 0  Santo Domingo  18.456792  -69.951164                   Assassination   1.0
# 1    Mexico city  19.371887  -99.086624     Hostage Taking (Kidnapping)   0.0
# 2        Unknown  15.478598  120.599741                   Assassination   1.0
# 3         Athens  37.997490   23.762728               Bombing/Explosion   NaN
# 4        Fukouka  33.580412  130.396361  Facility/Infrastructure Attack   NaN
#
#    WOUND                  target1 summary                               GROUP  \
# 0    0.0             Julio Guzman     NaN                              MANO-D
# 1    0.0  Nadine Chaval, daughter     NaN  23rd of September Communist League
# 2    0.0                 Employee     NaN                             Unknown
# 3    NaN             U.S. Embassy     NaN                             Unknown
# 4    NaN           U.S. Consulate     NaN                             Unknown
#
#                    TARGET_TYPE      WEAPON motive
# 0  Private Citizens & Property     Unknown    NaN
# 1      Government (Diplomatic)     Unknown    NaN
# 2          Journalists & Media     Unknown    NaN
# 3      Government (Diplomatic)  Explosives    NaN
# 4      Government (Diplomatic)  Incendiary    NaN

# %%
datanew.isnull().sum()
# Out:
# YEAR               0
# MONTH              0
# DAY                0
# COUNTRY            0
# STATE            181
# REGION             0
# city               0
# latitude        2485
# longitude       2485
# ATTACK_TYPE        0
# KILL            5706
# WOUND           7534
# target1          382
# summary        44743
# GROUP              1
# TARGET_TYPE        0
# WEAPON             1
# motive         45023
# dtype: int64

# %%
datanew.shape
# Out:
# (45964, 18)

# %%
datanew['WOUND'] = datanew['WOUND'].fillna(0)
datanew['KILL'] = datanew['KILL'].fillna(0)
datanew['GROUP'] = datanew['GROUP'].fillna(0)

# %%
datanew['COUNTRY'].value_counts().idxmax()  #most number of attacks
# Out:
# 'El Salvador'

# %%
datanew['REGION'].value_counts().idxmax()   #most number of attacks
# Out:
# 'South America'

# %%
datanew['YEAR'].value_counts().idxmax()     #most number of attacks
# Out:
# 1989

# %%
datanew['MONTH'].value_counts().idxmax()    #most number of attacks
# Out:
# 3

# %%
datanew['GROUP'].value_counts().idxmax()
# Out:
# 'Unknown'

# %%
datanew['ATTACK_TYPE'].value_counts().idxmax()  #Type of attacks
# Out:
# 'Bombing/Explosion'

# %%
datanew['YEAR'].unique()
# Out:
# array([1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980,
#        1981, 1986, 1982, 1983, 1984, 1985, 1987, 1988, 1989, 1990, 1991])

# %%
y = datanew['YEAR'].value_counts(dropna = False).sort_index()
y
# Out:
# 1970     651
# 1971     471
# 1972     568
# 1973     473
# 1974     581
# 1975     740
# 1976     923
# 1977    1319
# 1978    1526
# 1979    2662
# 1980    2662
# 1981    2586
# 1982    2544
# 1983    2870
# 1984    3495
# 1985    2915
# 1986    2860
# 1987    3183
# 1988    3721
# 1989    4324
# 1990    3887
# 1991    1003
# Name: YEAR, dtype: int64

# %%
plt.figure(figsize = (16,10))
sns.barplot(x = datanew['YEAR'].unique(),y = datanew['YEAR'].value_counts(dropna = False).sort_index(),palette = "ch:s=.25,rot=-.25")
plt.xticks(rotation = 50)
plt.xlabel('Year of attacks',fontsize=14)
plt.ylabel('Number of attacks',fontsize=14)
plt.title('Attacks In Years',fontsize=22)
plt.show()

# %%
pd.crosstab(datanew.YEAR, datanew.REGION).plot(kind='area',stacked=False,figsize=(18,10))
plt.title('Terrorist Activities By Region In Each Year',fontsize=24)
plt.ylabel('Number of Attacks',fontsize=18)
plt.xlabel("Year",fontsize=18)
plt.show()

# %%
country = datanew.COUNTRY.value_counts()[:10]
country
# Out:
# El Salvador       4829
# Peru              4785
# Colombia          3882
# United Kingdom    3148
# Spain             2375
# United States     2038
# Chile             2010
# Nicaragua         1787
# Guatemala         1712
# India             1648
# Name: COUNTRY, dtype: int64

# %%
datanew['city'].value_counts().to_frame().sort_values('city',axis=0,ascending=False).head(15).plot(kind='bar',figsize=(18,5), color='red')
plt.xticks(rotation = 45)
plt.xlabel("Cities",fontsize=15)
plt.ylabel("Number of Attacks",fontsize=15)
plt.title("Top 10 Most Effected City",fontsize=20)
plt.show()

# %%
datanew[['ATTACK_TYPE','KILL']].groupby(["ATTACK_TYPE"],axis=0).sum().plot(kind='bar',figsize=(20,10),color=['y'])
plt.xticks(rotation=50)
plt.title("Number of killed (by attack type) ",fontsize=25)
plt.ylabel('Number of people',fontsize=15)
plt.xlabel('Attack type',fontsize=15)
plt.xticks(rotation= 90, fontsize = 16)
plt.show()

# %%
datanew[['ATTACK_TYPE','WOUND']].groupby(["ATTACK_TYPE"],axis=0).sum().plot(kind='bar',figsize=(20,10),color=['r'])
plt.xticks(rotation=50)
plt.title("Number of wounded  ",fontsize=25)
plt.ylabel('Number of people',fontsize=18)
plt.xlabel('Attack type',fontsize=18)
plt.xticks(rotation= 90, fontsize = 18)
plt.show()

# %%
datanew[['GROUP','KILL']].groupby(['GROUP'],axis=0).sum().drop('Unknown').sort_values('KILL',ascending=False).head(10).plot(kind='bar',color='blue',figsize=(20,10))
plt.title("Top 10 terrorist group attack",fontsize=25)
plt.xlabel("terrorist group name",fontsize=22)
plt.ylabel("No of killed people",fontsize=22)
plt.xticks(rotation= 90, fontsize = 18)
plt.show()

# %%
fatality=datanew[['YEAR','KILL']].groupby(['YEAR']).sum()
fig,ax4 = plt.subplots(figsize=(18,10))
fatality.plot(kind='bar',alpha=0.7,ax=ax4, color='g')
plt.xticks(rotation = 90)
plt.title("PEOPLE DIED DUE TO ATTACK YEAR WISE",fontsize=20)
plt.ylabel("Number of people killed",fontsize=16)
plt.xlabel('Year',fontsize=16)
plt.show()

# %%
terrorism=datanew[['GROUP','COUNTRY','KILL']]
terrorism=terrorism.groupby(['GROUP','COUNTRY'],axis=0).sum().sort_values('KILL',ascending=False).drop('Unknown').reset_index().head(12)
terrorism
# Out:
#                                                GROUP         COUNTRY    KILL
# 0                                  Shining Path (SL)            Peru  9558.0
# 1   Farabundo Marti National Liberation Front (FMLN)     El Salvador  7690.0
# 2                  Nicaraguan Democratic Force (FDN)       Nicaragua  6630.0
# 3            Liberation Tigers of Tamil Eelam (LTTE)       Sri Lanka  3652.0
# 4                            New People's Army (NPA)     Philippines  2517.0
# 5      Revolutionary Armed Forces of Colombia (FARC)        Colombia  2087.0
# 6      Mozambique National Resistance Movement (MNR)      Mozambique  2074.0
# 7           Democratic Revolutionary Alliance (ARDE)       Nicaragua  1803.0
# 8                        Irish Republican Army (IRA)  United Kingdom  1614.0
# 9                                    Sikh Extremists           India  1575.0
# 10                                            Tamils       Sri Lanka  1387.0
# 11                       M-19 (Movement of April 19)        Colombia  1317.0

# %%
total_kill = datanew.loc[:,'KILL']
print('Total number of people killed by terrorist attack is', int(sum(total_kill.dropna())))
# Out:
# Total number of people killed by terrorist attack is 83729

# %%
kill_type = datanew.pivot_table(columns='ATTACK_TYPE', values='KILL', aggfunc='sum')
kill_type
# Out:
# ATTACK_TYPE  Armed Assault  Assassination  Bombing/Explosion  \
# KILL               47380.0        10411.0            17850.0
#
# ATTACK_TYPE  Facility/Infrastructure Attack  Hijacking  \
# KILL                                 1166.0      427.0
#
# ATTACK_TYPE  Hostage Taking (Barricade Incident)  Hostage Taking (Kidnapping)  \
# KILL                                       496.0                       1336.0
#
# ATTACK_TYPE  Unarmed Assault  Unknown
# KILL                    89.0   4574.0

# %%
Kill_wrt_country = datanew.pivot_table(columns='COUNTRY', values='KILL', aggfunc='sum')
Kill_wrt_country
# Out:
# COUNTRY  Afghanistan  Albania  Algeria  Andorra  Angola  Argentina  Australia  \
# KILL           219.0      0.0      5.0      0.0  1005.0      366.0        7.0
#
# COUNTRY  Austria  Bahamas  Bahrain  Bangladesh  Barbados  Belgium  Belize  \
# KILL        21.0      0.0      0.0       407.0      73.0     30.0     2.0
#
# COUNTRY  Bolivia  Botswana  Brazil  Brunei  Bulgaria  Burkina Faso  Cambodia  \
# KILL        25.0      11.0    77.0     0.0       2.0           1.0      31.0
#
# COUNTRY  Canada  Central African Republic  Chad  Chile  China  Colombia  \
# KILL      349.0                       3.0   0.0  196.0   22.0    7231.0
#
# COUNTRY  Costa Rica  Cyprus  Czechoslovakia  Denmark  Djibouti  Dominica  \
# KILL           12.0    40.0            26.0      1.0      16.0       3.0
#
# COUNTRY  Dominican Republic  East Germany (GDR)  Ecuador  Egypt  El Salvador  \
# KILL                   22.0                 2.0     43.0  111.0      11644.0
#
# COUNTRY  Ethiopia  Falkland Islands  Fiji  Finland  France  French Guiana  \
# KILL        393.0               0.0   0.0      0.0   193.0            1.0
#
# COUNTRY  Gabon  Germany  Ghana  Greece  Grenada  Guadeloupe  Guatemala  \
# KILL       2.0      1.0    0.0   232.0      9.0         7.0     4966.0
#
# COUNTRY  Guinea  Guyana  Haiti  Honduras  Hong Kong  Hungary  Iceland   India  \
# KILL        1.0     8.0   31.0     204.0        0.0      0.0      0.0  4201.0
#
# COUNTRY  Indonesia    Iran   Iraq  Ireland  Israel  Italy  Jamaica  Japan  \
# KILL         111.0  1076.0  161.0    103.0   446.0  394.0     23.0   23.0
#
# COUNTRY  Jordan  Kenya  Kuwait  Laos  Lebanon  Lesotho  Liberia  Libya  \
# KILL       14.0   50.0    23.0   2.0   2942.0     45.0      2.0   15.0
#
# COUNTRY  Luxembourg  Malaysia  Maldives  Mali  Malta  Martinique  Mauritania  \
# KILL            0.0     134.0      19.0  17.0    2.0         0.0         4.0
#
# COUNTRY  Mauritius  Mexico  Morocco  Mozambique  Myanmar  Namibia  Nepal  \
# KILL           0.0   106.0    212.0      2193.0    366.0    179.0    6.0
#
# COUNTRY  Netherlands  New Caledonia  New Hebrides  New Zealand  Nicaragua  \
# KILL            26.0           35.0           0.0          1.0    10473.0
#
# COUNTRY  Niger  Nigeria  North Yemen  Norway  Pakistan  Panama  \
# KILL     175.0      8.0          3.0     1.0     716.0     5.0
#
# COUNTRY  Papua New Guinea  Paraguay  People's Republic of the Congo     Peru  \
# KILL                 28.0       6.0                            15.0  10167.0
#
# COUNTRY  Philippines  Poland  Portugal  Qatar  Republic of the Congo  \
# KILL          3847.0     1.0      30.0    4.0                    0.0
#
# COUNTRY  Rhodesia  Romania  Rwanda  Saudi Arabia  Senegal  Seychelles  \
# KILL        217.0      3.0     0.0          69.0     23.0         0.0
#
# COUNTRY  Singapore  Somalia  South Africa  South Korea  South Vietnam  \
# KILL           4.0     39.0         920.0          8.0           81.0
#
# COUNTRY  South Yemen  Soviet Union  Spain  Sri Lanka  Sudan  Suriname  \
# KILL             0.0          71.0  891.0     7403.0  390.0      28.0
#
# COUNTRY  Swaziland  Sweden  Switzerland  Syria  Taiwan  Tanzania  Thailand  \
# KILL           5.0     8.0         52.0  505.0    25.0       1.0     267.0
#
# COUNTRY  Togo  Trinidad and Tobago  Tunisia  Turkey  Uganda  \
# KILL      1.0                  0.0     45.0  1450.0   776.0
#
# COUNTRY  United Arab Emirates  United Kingdom  United States  Uruguay  \
# KILL                    122.0          2933.0          243.0      5.0
#
# COUNTRY  Vatican City  Venezuela  West Bank and Gaza Strip  \
# KILL              0.0      117.0                     226.0
#
# COUNTRY  West Germany (FRG)  Western Sahara  Yemen  Yugoslavia  Zaire  Zambia  \
# KILL                   97.0             1.0    0.0         6.0   31.0    69.0
#
# COUNTRY  Zimbabwe
# KILL        136.0
